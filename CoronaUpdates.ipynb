# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 20

# %%
import requests
url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]

# %%
df.head()
# Out:
#   Country,Other  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 0         World     1614882  +11,230      96791.0    +1,099        362538.0
# 1           USA      468895     +329      16697.0        +6         25928.0
# 2         Spain      157022   +3,800      15843.0      +396         55668.0
# 3         Italy      143626      NaN      18279.0       NaN         28470.0
# 4       Germany      118235      NaN       2607.0       NaN         52407.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0      1155553           49122.0             207.0           12.4         NaN
# 1       426270           10011.0            1417.0           50.0   2376977.0
# 2        85511            7371.0            3358.0          339.0    355000.0
# 3        96877            3605.0            2375.0          302.0    853369.0
# 4        63221            4895.0            1411.0           31.0   1317887.0
#
#    Tests/ 1M pop
# 0            NaN
# 1         7181.0
# 2         7593.0
# 3        14114.0
# 4        15730.0

# %%
df.shape
# Out:
# (214, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 12 columns):
# Country,Other       214 non-null object
# TotalCases          214 non-null int64
# NewCases            68 non-null object
# TotalDeaths         163 non-null float64
# NewDeaths           39 non-null object
# TotalRecovered      183 non-null float64
# ActiveCases         214 non-null int64
# Serious,Critical    130 non-null float64
# Tot Cases/1M pop    212 non-null float64
# Deaths/1M pop       161 non-null float64
# TotalTests          154 non-null float64
# Tests/ 1M pop       154 non-null float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 20.2+ KB

# %%
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']

# %%
df.head()
# Out:
#    Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 0    World     1614882  +11,230      96791.0    +1,099        362538.0
# 1      USA      468895     +329      16697.0        +6         25928.0
# 2    Spain      157022   +3,800      15843.0      +396         55668.0
# 3    Italy      143626      NaN      18279.0       NaN         28470.0
# 4  Germany      118235      NaN       2607.0       NaN         52407.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0      1155553           49122.0             207.0           12.4         NaN
# 1       426270           10011.0            1417.0           50.0   2376977.0
# 2        85511            7371.0            3358.0          339.0    355000.0
# 3        96877            3605.0            2375.0          302.0    853369.0
# 4        63221            4895.0            1411.0           31.0   1317887.0
#
#    Tests/ 1M pop
# 0            NaN
# 1         7181.0
# 2         7593.0
# 3        14114.0
# 4        15730.0

# %%
df.tail()
# Out:
#                    Country  TotalCases NewCases  TotalDeaths NewDeaths  \
# 209            Timor-Leste           2       +1          NaN       NaN
# 210  Saint Pierre Miquelon           1      NaN          NaN       NaN
# 211                  Yemen           1       +1          NaN       NaN
# 212                  China       81907      +42       3336.0        +1
# 213                 Total:     1614882  +11,230      96791.0    +1,099
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 209             1.0            1               NaN              2.00
# 210             NaN            1               NaN            173.00
# 211             NaN            1               NaN              0.03
# 212         77455.0         1116             144.0             57.00
# 213        362538.0      1155553           49122.0            207.20
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 209            NaN         NaN            NaN
# 210            NaN         NaN            NaN
# 211            NaN         NaN            NaN
# 212            2.0         NaN            NaN
# 213           12.4         NaN            NaN

# %%
df = df[1:-1]

# %%
df.head()
# Out:
#    Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 1      USA      468895     +329      16697.0        +6         25928.0
# 2    Spain      157022   +3,800      15843.0      +396         55668.0
# 3    Italy      143626      NaN      18279.0       NaN         28470.0
# 4  Germany      118235      NaN       2607.0       NaN         52407.0
# 5   France      117749      NaN      12210.0       NaN         23206.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 1       426270           10011.0            1417.0           50.0   2376977.0
# 2        85511            7371.0            3358.0          339.0    355000.0
# 3        96877            3605.0            2375.0          302.0    853369.0
# 4        63221            4895.0            1411.0           31.0   1317887.0
# 5        82333            7066.0            1804.0          187.0    333807.0
#
#    Tests/ 1M pop
# 1         7181.0
# 2         7593.0
# 3        14114.0
# 4        15730.0
# 5         5114.0

# %%
df.tail()
# Out:
#                    Country  TotalCases NewCases  TotalDeaths NewDeaths  \
# 208       Papua New Guinea           2      NaN          NaN       NaN
# 209            Timor-Leste           2       +1          NaN       NaN
# 210  Saint Pierre Miquelon           1      NaN          NaN       NaN
# 211                  Yemen           1       +1          NaN       NaN
# 212                  China       81907      +42       3336.0        +1
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 208             NaN            2               NaN              0.20
# 209             1.0            1               NaN              2.00
# 210             NaN            1               NaN            173.00
# 211             NaN            1               NaN              0.03
# 212         77455.0         1116             144.0             57.00
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 208            NaN        72.0            8.0
# 209            NaN         NaN            NaN
# 210            NaN         NaN            NaN
# 211            NaN         NaN            NaN
# 212            2.0         NaN            NaN

# %%
df[0:1]
# Out:
#   Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 1     USA      505204   +2,328      18849.0      +102         27369.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 1       458986           10947.0            1526.0           57.0   2549542.0
#
#    Tests/ 1M pop
# 1         7702.0

# %%
df[-1:]
# Out:
#     Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 212   China       81953      +46       3339.0        +3         77525.0
#
#      ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  \
# 212         1089             141.0              57.0            2.0
#
#      TotalTests  Tests/ 1M pop
# 212         NaN            NaN

# %%
df.head()
# Out:
#    Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 1      USA      505204   +2,328      18849.0      +102         27369.0
# 2    Spain      161852   +3,579      16353.0      +272         59109.0
# 3    Italy      147577      NaN      18849.0       NaN         30455.0
# 4   France      124869      NaN      13197.0       NaN         24932.0
# 5  Germany      122855     +684       2736.0       NaN         53913.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 1       458986           10947.0            1526.0           57.0   2549542.0
# 2        86390            7371.0            3462.0          350.0    355000.0
# 3        98273            3497.0            2441.0          312.0    906864.0
# 4        86740            7004.0            1913.0          202.0    333807.0
# 5        66206            4895.0            1466.0           33.0   1317887.0
#
#    Tests/ 1M pop
# 1         7702.0
# 2         7593.0
# 3        14999.0
# 4         5114.0
# 5        15730.0

# %%
df['TotalCases']
# Out:
# 1      505204
# 2      161852
# 3      147577
# 4      124869
# 5      122855
#         ...
# 208         2
# 209         2
# 210         1
# 211         1
# 212     81953
# Name: TotalCases, Length: 212, dtype: int64

# %%
sort_df = df.sort_values('TotalCases', ascending=False)
sort_df.head()
# Out:
#    Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 1      USA      505204   +2,328      18849.0      +102         27369.0
# 2    Spain      161852   +3,579      16353.0      +272         59109.0
# 3    Italy      147577      NaN      18849.0       NaN         30455.0
# 4   France      124869      NaN      13197.0       NaN         24932.0
# 5  Germany      122855     +684       2736.0       NaN         53913.0
#
#    ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 1       458986           10947.0            1526.0           57.0   2549542.0
# 2        86390            7371.0            3462.0          350.0    355000.0
# 3        98273            3497.0            2441.0          312.0    906864.0
# 4        86740            7004.0            1913.0          202.0    333807.0
# 5        66206            4895.0            1466.0           33.0   1317887.0
#
#    Tests/ 1M pop
# 1         7702.0
# 2         7593.0
# 3        14999.0
# 4         5114.0
# 5        15730.0

# %%
print(total['TotalCases'].values[0])
# Out:
# 1725126

# %%
import random
import requests
import pandas as pd
import time
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']  = 12, 6
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 20

url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']
world = df[0:1]
total = df[-1:]
df = df[1:-1]
df = df.sort_values('TotalCases', ascending=False)
choices = [ '1', '2', '3', '4', '5', '6', '7', '8', '9', 'a','b', 'c', 'd', 'e']
def make_color():
    ch = [ random.choice(choices) for i in range(6)]
    return "#"+"".join(ch)
colors = []
while len(colors) != 30:
    color = make_color()
    if color in colors:
        continue
    colors.append(color)
#df.iloc[0, 1] = 468895
fig, ax = plt.subplots()
ax.bar(df['Country'][:30], df['TotalCases'][:30], color=colors)
ax.set_xticklabels(df['Country'][:30],rotation=90)
ax.set_ylim([0, 175000])
ax.set_yticklabels(range(0,1800000, 200000))
ax.set_title("Infected Corona Patients Till Now", fontsize=25, color='red', pad=80)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Countries')
ax.set_ylabel("Total Cases")
c = 1
for patch,color,lb in zip(ax.patches, colors, ax.get_xticklabels()):
    x  = patch.get_x() + 0.2
    h = patch.get_height()
    y = h + 10000 if c != 1 else 180000 
    if c == 1:
        text = df.iloc[0, 1]
    else:
        text = h
    c += 1
    ax.text(x, y, text, fontsize=20, color=color, rotation=90)
    lb.set_color(color)
    
c = "#000000"
i = 6
for ylb in ax.get_yticklabels():
    c = list(c)
    if i <= 9:
        c[1] = str(i)
        c[2] = str(i)
    else:
        c[1] = chr(i+97-10)
        c[2] = chr(i+97-10)
    c = "".join(c)
    i += 1
    ylb.set_color(c)
#plt.tight_layout()
plt.text(18, 150000, f"World - {world['TotalCases'][0]}", fontsize=20, color='blue')
plt.text(18, 180000, f"{time.strftime('%d %b, %Y %I:%M %p')}", fontsize=20, color="#333333")
plt.text(18, 130000, f"India - {india['TotalCases'].values[0]}", fontsize=20, color='green')
plt.show()

# %%
plt.text(18, 13000, f"India - {india['TotalDeaths'].values[0]}", fontsize=20, color='green')
# Out:
# Index(['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
#        'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
#        'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop'],
#       dtype='object')

# %%
import random
import requests
import pandas as pd
import time
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']  = 12, 6
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 20

url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']
world = df[0:1]
total = df[-1:]
df = df[1:-1]
df = df.sort_values('TotalCases', ascending=False)
df = df[['Country','TotalDeaths']]
df = df.sort_values('TotalDeaths', ascending=False)
choices = [ '1', '2', '3', '4', '5', '6', '7', '8', '9', 'a','b', 'c', 'd', 'e']
def make_color():
    ch = [ random.choice(choices) for i in range(6)]
    return "#"+"".join(ch)
colors = []
while len(colors) != 30:
    color = make_color()
    if color in colors:
        continue
    colors.append(color)
#df.iloc[0, 1] = 468895
fig, ax = plt.subplots()
ax.bar(df['Country'][:30], df['TotalDeaths'][:30], color=colors)
ax.set_xticklabels(df['Country'][:30],rotation=90)
ax.set_ylim([0, 25000])
#ax.set_yticklabels(range(0,25000, 1000))
ax.set_yticks(range(0, 25000, 2000))
ax.set_title("Corona Deaths Till Now", fontsize=25, color='red', pad=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Countries')
ax.set_ylabel("Total Deaths")

for patch,color,lb in zip(ax.patches, colors, ax.get_xticklabels()):
    x  = patch.get_x() + 0.2
    h = patch.get_height()
    y = h + 1000
    text = h
    ax.text(x, y, text, fontsize=20, color=color, rotation=90)
    lb.set_color(color)
    
c = "#000000"
i = 3
for ylb in ax.get_yticklabels():
    c = list(c)
    if i <= 9:
        c[1] = str(i)
        c[2] = str(i)
    else:
        c[1] = chr(i+97-10)
        c[2] = chr(i+97-10)
    c = "".join(c)
    i += 1
    ylb.set_color(c)
#plt.tight_layout()
plt.text(18, 15000, f"World - {world['TotalDeaths'][0]}", fontsize=20, color='blue')
plt.text(18, 19000, f"{time.strftime('%d %b, %Y %I:%M %p')}", fontsize=20, color="#333333")
plt.text(18, 13000, f"India - {india['TotalDeaths'].values[0]}", fontsize=20, color='green')
plt.show()

# %%
import random
import requests
import pandas as pd
import time
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']  = 12, 6
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 20

url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']

df['NewCases'] = df['NewCases'].apply(lambda x: ''.join(x.split(',')) if type(x) == str else x).values.astype(float)
df = df[~df['NewCases'].isna()][['Country', 'NewCases']]
df.sort_values('NewCases', ascending=False, inplace=True)
world = df[0:1]`
df = df[2:]
choices = [ '1', '2', '3', '4', '5', '6', '7', '8', '9', 'a','b', 'c', 'd', 'e']
def make_color():
    ch = [ random.choice(choices) for i in range(6)]
    return "#"+"".join(ch)
colors = []
while len(colors) != 30:
    color = make_color()
    if color in colors:
        continue
    colors.append(color)
#df.iloc[0, 1] = 468895
fig, ax = plt.subplots()
ax.bar(df['Country'][:30], df['NewCases'][:30], color=colors)
ax.set_xticklabels(df['Country'][:30],rotation=90)
ax.set_ylim([0, 6000])
#ax.set_yticklabels(range(0,25000, 1000))
ax.set_yticks(range(0, 6000, 1000))
ax.set_title("New Corona Cases", fontsize=25, color='red', pad=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Countries')
ax.set_ylabel("New Cases")
c = 1
for patch,color,lb in zip(ax.patches, colors, ax.get_xticklabels()):
    x  = patch.get_x() + 0.2
    h = patch.get_height()
    y = h + 500
    if y >= 6000:
        y = 6500
    text = h
    ax.text(x, y, text, fontsize=20, color=color, rotation=90)
    lb.set_color(color)
    
c = "#000000"
i = 9
for ylb in ax.get_yticklabels():
    c = list(c)
    if i <= 9:
        c[1] = str(i)
        c[2] = str(i)
    else:
        c[1] = chr(i+97-10)
        c[2] = chr(i+97-10)
    c = "".join(c)
    i += 1
    ylb.set_color(c)
#plt.tight_layout()
plt.text(18, 4000, f"World - {world['NewCases'][0]}", fontsize=20, color='blue')
plt.text(18, 5000, f"{time.strftime('%d %b, %Y %I:%M %p')}", fontsize=20, color="#333333")
plt.text(18, 3000, f"India - {india['NewCases'].values[0]}", fontsize=20, color='green')
plt.show()

# %%
plt.text(18, 700, f"India - {india['NewDeaths'].values[0]}", fontsize=20, color='green')

# %%
import random
import requests
import pandas as pd
import time
import matplotlib.pyplot as plt
#%matplotlib inline
plt.rcParams['figure.figsize']  = 12, 6
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 20

url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']
india = df[df['Country'] == 'India']
df['NewDeaths'] = df['NewDeaths'].apply(lambda s:"".join(s.split(',')) if type(s) == str else s).astype(float)
df = df[~df['NewDeaths'].isna()]

df.sort_values('NewDeaths', ascending=False, inplace=True)
df = df[['Country', 'NewDeaths']]
df.sort_values('NewDeaths', ascending=False, inplace=True)
world = df[0:1]
df = df[2:]
choices = [ '1', '2', '3', '4', '5', '6', '7', '8', '9', 'a','b', 'c', 'd', 'e']
def make_color():
    ch = [ random.choice(choices) for i in range(6)]
    return "#"+"".join(ch)
colors = []
while len(colors) != 30:
    color = make_color()
    if color in colors:
        continue
    colors.append(color)
#df.iloc[0, 1] = 468895
fig, ax = plt.subplots()
ax.bar(df['Country'][:30], df['NewDeaths'][:30], color=colors)
ax.set_xticklabels(df['Country'][:30],rotation=90)
ax.set_ylim([0, 1400])
ax.set_yticks(range(0,1400, 100))
ax.set_title("New Deaths Due To Corona", fontsize=25, color='red', pad=80)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Countries')
ax.set_ylabel("Total Cases")

for patch,color,lb in zip(ax.patches, colors, ax.get_xticklabels()):
    x  = patch.get_x() + 0.2
    h = patch.get_height()
    y = h + 100
    text = h
    
    ax.text(x, y, text, fontsize=20, color=color, rotation=90)
    lb.set_color(color)
    
c = "#000000"
i = 1
for ylb in ax.get_yticklabels():
    c = list(c)
    if i <= 9:
        c[1] = str(i)
        c[2] = str(i)
    else:
        c[1] = chr(i+97-10)
        c[2] = chr(i+97-10)
    c = "".join(c)
    i += 1
    ylb.set_color(c)
#plt.tight_layout()
plt.text(18, 800, f"World - {world['NewDeaths'][0]}", fontsize=20, color='blue')
plt.text(18, 1000, f"{time.strftime('%d %b, %Y %I:%M %p')}", fontsize=20, color="#333333")
plt.text(18, 600, f"India - {india['NewDeaths'].values[0]}", fontsize=20, color='green')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
url = "https://www.worldometers.info/coronavirus/"
page = requests.get(url)
data = pd.read_html(page.content)
df = data[0]
df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
       'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop',
       'Deaths/1M pop', 'TotalTests', 'Tests/ 1M pop']

# %%
india = df[df['Country'] == 'India']

# %%
india
# Out:
#    Country  TotalCases NewCases  TotalDeaths NewDeaths  TotalRecovered  \
# 20   India        8339     +739        249.0       NaN           774.0
#
#     ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  \
# 20         7316               NaN               6.0            0.2
#
#     TotalTests  Tests/ 1M pop
# 20    189111.0          137.0

# %%
india['NewDeaths'].values[0]
# Out:
# nan

# %%
df['C']

# %%
df[df['Country'] == 'India']
# Out:
# Empty DataFrame
# Columns: [Country, NewDeaths]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 1 to 211
# Data columns (total 12 columns):
# Country             212 non-null object
# TotalCases          212 non-null int64
# NewCases            114 non-null object
# TotalDeaths         161 non-null float64
# NewDeaths           65 non-null object
# TotalRecovered      183 non-null float64
# ActiveCases         212 non-null int64
# Serious,Critical    127 non-null float64
# Tot Cases/1M pop    210 non-null float64
# Deaths/1M pop       159 non-null float64
# TotalTests          155 non-null float64
# Tests/ 1M pop       155 non-null float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 31.5+ KB

# %%
df['NewDeaths'] = df['NewDeaths'].apply(lambda s:"".join(s.split(',')) if type(s) == str else s).astype(float)
df = df[~df['NewDeaths'].isna()]

df.sort_values('NewDeaths', ascending=False, inplace=True)
df = df[['Country', 'NewDeaths']]
df.sort_values('NewDeaths', ascending=False, inplace=True)

# %%
df['NewDeaths'] = df['NewDeaths'].apply(lambda s:"".join(s.split(',')) if type(s) == str else s).astype(float)

# %%
sum(df['NewDeaths'].isna())
# Out:
# 147

# %%
df = df[~df['NewDeaths'].isna()]

# %%
df = df[['Country', 'NewDeaths']]
df.head()
# Out:
#     Country  NewDeaths
# 1       USA     1086.0
# 2     Spain      272.0
# 3     Italy      619.0
# 212   China        3.0
# 6        UK      917.0

# %%
df.sort_values('NewDeaths', ascending=False, inplace=True)
df.head()
# Out:
#    Country  NewDeaths
# 1      USA     1086.0
# 6       UK      917.0
# 3    Italy      619.0
# 9  Belgium      327.0
# 2    Spain      272.0

# %%
212-147
# Out:
# 65

# %%
df.shape
# Out:
# (65, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 1 to 211
# Data columns (total 12 columns):
# Country             212 non-null object
# TotalCases          212 non-null int64
# NewCases            114 non-null object
# TotalDeaths         161 non-null float64
# NewDeaths           65 non-null float64
# TotalRecovered      183 non-null float64
# ActiveCases         212 non-null int64
# Serious,Critical    127 non-null float64
# Tot Cases/1M pop    210 non-null float64
# Deaths/1M pop       159 non-null float64
# TotalTests          155 non-null float64
# Tests/ 1M pop       155 non-null float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 31.5+ KB

# %%
df['NewCases'].apply(lambda x: "".join(x.split(',')) if ',' in x else 0 if x == np.nan else x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-0843c92a1347> in <module>
# ----> 1 df['NewCases'].apply(lambda x: "".join(x.split(',')) if ',' in x else 0 if x == np.nan else x)
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-57-0843c92a1347> in <lambda>(x)
# ----> 1 df['NewCases'].apply(lambda x: "".join(x.split(',')) if ',' in x else 0 if x == np.nan else x)
#
# TypeError: argument of type 'float' is not iterable

# %%
df['NewCases'] = df['NewCases'].apply(lambda x: ''.join(x.split(',')) if type(x) == str else x).values.astype(float)
new_cases = df[~df['NewCases'].isna()][['Country', 'NewCases']]

# %%
df.shape
# Out:
# (212, 12)

# %%
sum(df['NewCases'].isna())
# Out:
# 103

# %%
212-103
# Out:
# 109

# %%
new_cases = df[~df['NewCases'].isna()][['Country', 'NewCases']]

# %%
new_cases.head()
# Out:
#      Country  NewCases
# 1        USA    5182.0
# 2      Spain    3579.0
# 3      Italy    4694.0
# 5    Germany    1655.0
# 212    China      46.0

# %%
new_cases.sort_values('NewCases', ascending=False, inplace=True)
new_cases = new_cases.head(30)
plt.bar(new_cases['Country'], new_cases['NewCases'])
plt.xticks(rotation=90)
plt.show()

# %%
new_cases.head(30)
# Out:
#          Country  NewCases
# 6             UK    5233.0
# 1            USA    5182.0
# 3          Italy    4694.0
# 2          Spain    3579.0
# 7           Iran    1837.0
# 16        Russia    1667.0
# 5        Germany    1655.0
# 9        Belgium    1351.0
# 11   Netherlands    1316.0
# 29       Romania     523.0
# 14      Portugal     515.0
# 19        Sweden     466.0
# 21         India     463.0
# 23         Chile     426.0
# 12        Canada     411.0
# 36        Mexico     403.0
# 25        Poland     401.0
# 35  Saudi Arabia     382.0
# 38           UAE     376.0
# 10   Switzerland     349.0
# 37     Indonesia     330.0
# 46       Ukraine     308.0
# 32      Pakistan     275.0
# 39        Serbia     275.0
# 49       Belarus     245.0
# 15       Austria     235.0
# 34   Philippines     233.0
# 13        Brazil     233.0
# 43         Qatar     216.0
# 48     Singapore     191.0

# %%
import numpy as np

# %%
a = np.array([1,2,2,])

# %%
a.astype(float)
# Out:
# array([1., 2., 2.])

# %%
df.columns
# Out:
# Index(['Country', 'TotalDeaths'], dtype='object')

# %%
x = [ 1, 2, 3, 4, 5]
y1 = [ 10, 30, 25, 35, 20, ]
y2 = [ 15, 20, 40, 25, 35]

# %%
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
x = [ 1, 2, 3, 4, 5]
normal = [ 10, 30, 25, 35, 20, ]
special = [ 15, 20, 40, 25, 35]
fig, ax = plt.subplots()
country=[ 'india', 'us', 'china', 'uk', 'some']
ax.bar([1, 3, 5, 7, 9], y1, color='orange', label='normal')
ax.bar([2, 4, 6, 8, 10], y2, color='red' , label='special')
ax.set_xticklabels(country)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
country=[ 'india', 'us', 'china', 'uk', 'some']
ax.bar(x, y1, color='orange', align='edge', width=0.5, label='deaths')
ax.bar(x, y2, color='red' ,width=0.4, label='cases')
ax.set_xticklabels(country)
plt.legend()
plt.show()

# %%
ax.set_xticklabels()
# Out:
# <bound method _AxesBase.set_xticklabels of <matplotlib.axes._subplots.AxesSubplot object at 0x000002559CFE0FC8>>

# %%
x =  [ 1, 2, 3, 4, 5]
y1 = [ 10, 30, 25, 35, 20, ]
y2  = [ 15, 20, 40, 25, 35]
y3 = [ 12, 24, 15, 17, 24]
plt.stackplot(x, y1, y2, y3, labels=['one', 'two', 'three'])
plt.xticks(range(1,6))
plt.legend()
plt.show()

# %%
plt.x
